# %% [markdown]
# # Collabrative Filtering

# %%
#testing, OCRing the file using tesseract
import pytesseract
pytesseract.pytesseract.tesseract_cmd = 'C:/Users/cyadav/AppData/Local/Programs/Tesseract-OCR/tesseract.exe'

# %%
import cv2
from PIL import Image
img1 = Image.open('Capture.PNG')
img = cv2.imread('Capture.PNG')
exttext = pytesseract.image_to_string(img)

# %%
cor = pytesseract.image_to_boxes(img1)
cor
# Out:
# "‘ 0 198 8 204 0\nT 8 187 20 202 0\nh 20 187 26 204 0\ni 26 187 33 198 0\ns 34 187 48 204 0\ny 51 182 64 198 0\ne 64 187 74 198 0\na 74 187 84 198 0\nr 85 187 93 198 0\n' 94 198 97 204 0\ns 97 187 105 198 0\nW 109 187 130 202 0\no 126 187 135 204 0\nr 129 187 139 198 0\nl 141 187 154 204 0\nd 156 187 167 204 0\nP 172 187 183 202 0\no 183 187 194 198 0\np 195 181 206 198 0\nu 207 187 219 198 0\nl 220 187 225 204 0\na 226 187 236 198 0\nt 238 187 244 201 0\ni 245 187 251 204 0\no 252 187 263 198 0\nn 264 187 276 198 0\nD 281 187 295 202 0\na 291 182 300 202 0\ny 296 182 318 198 0\n[ 324 181 329 204 0\nJ 324 181 335 204 0\nu 336 187 355 204 0\nl 346 181 354 204 0\ny 354 182 367 198 0\n1 371 187 381 202 0\n1 382 187 393 202 0\n] 393 181 398 204 0\nf 405 187 414 204 0\na 412 187 422 198 0\nl 423 187 429 204 0\nl 430 187 435 204 0\ns 437 187 444 198 0\nd 450 187 461 204 0\nu 462 187 474 198 0\nr 475 187 489 204 0\ni 483 181 494 204 0\nn 490 187 502 198 0\ng 503 181 514 198 0\na 518 187 528
# ...

# %%
img
# Out:
# array([[[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        ...,
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
# ...

# %%
words = exttext.split()

# %%
from nltk.corpus import stopwords
stop = stopwords.words('english')

# %%
appendFile = ''
for r in words:
                if not r in stop:
                    print(r)
# Out:
# ‘This
# year’s
# World
# Population
# Day
# [July
# 11]
# falls
# milestone
# year,
# anticipate
# birth
# Earth’s
# eight
# billionth
# inhabitant.
# This
# occasion
# celebrate
# diversity,
# recognise
# common
# humanity,
# marvel
# advancements
# health
# extended
# lifespans
# dramatically
# reduced
# maternal
# child
# mortality
# rates,”
# U.N.
# Secretary-
# General
# Antonio
# Guterres
# said.

# %%
words
# Out:
# ['‘This',
#  'year’s',
#  'World',
#  'Population',
#  'Day',
#  '[July',
#  '11]',
#  'falls',
#  'during',
#  'a',
#  'milestone',
#  'year,',
#  'when',
#  'we',
#  'anticipate',
#  'the',
#  'birth',
#  'of',
#  'the',
#  'Earth’s',
#  'eight',
#  'billionth',
#  'inhabitant.',
#  'This',
#  'is',
#  'an',
#  'occasion',
#  'to',
#  'celebrate',
#  'our',
#  'diversity,',
#  'recognise',
#  'our',
#  'common',
#  'humanity,',
#  'and',
#  'marvel',
#  'at',
#  'advancements',
#  'in',
#  'health',
#  'that',
#  'have',
#  'extended',
#  'lifespans',
#  'and',
#  'dramatically',
#  'reduced',
#  'maternal',
#  'and',
#  'child',
#  'mortality',
#  'rates,”',
#  'U.N.',
#  'Secretary-',
#  'General',
#  'Antonio',
#  'Guterres',
#  'said.']

# %%
from IPython.display import Image
Image(filename='Capture.PNG')

# %%
import cv2

image = cv2.imread('Capture.PNG')
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)  #convert to grayscale

#convert to binary

(thresh, binary) = cv2.threshold(gray, 150, 255, cv2.THRESH_BINARY | cv2.THRESH_OTSU) # convert2binary
cv2.imshow('binary', binary)
cv2.imwrite('binary.png', binary)
# Out:
# True

# %%
import nltk
from nltk.tokenize import word_tokenize

# %%
from nltk.tag import pos_tag

# %%
sent = nltk.word_tokenize(exttext)

# %%
sent = nltk.pos_tag(sent)

# %%
import spacy

# %%
ner = spacy.load(r'C:\Users\cyadav\en_core_web_sm-3.3.0.tar\dist\en_core_web_sm-3.3.0\en_core_web_sm-3.3.0\en_core_web_sm\en_core_web_sm-3.3.0')

# %%
str2 = 'John is working in Google inc'
text1 = ner(exttext)

# %%
for word in text1.ents:
    print(word.text,word.label_)
# Out:
# year DATE
# World Population Day EVENT
# July 11 DATE
# a milestone year DATE
# Earth LOC
# eight billionth DATE
# U.N. ORG
# Antonio Guterres PERSON

# %%
from spacy import displacy
displacy.render(text1,style="ent",jupyter=True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">‘This
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     year
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# ’s
# <mark class="entity" style="background: #ffeb80; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     World Population Day
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">EVENT</span>
# </mark>
#  [
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     July 11
# ...

# %%
def func(value):
    return ''.join(value.splitlines())

# %%
exttext = func(exttext)

# %%
str1 = ""
# traverse in the string 
for i in words:
    str1 += i + ' ' 
print(str1)
# Out:
# DEPARTMENT OF HOMELAND SECURITY Federal Emergency Management Agency OMB Controi No. 1660-0040 STANDARD FLOOD HAZARD DETERMINATION FORM (SFHDF) Expires: 10/31/18 SECTION | - LOAN INFORMATION 1. LENDER/SERVICER NAME AND ADDRESS 2. COLLATERAL DESCRIPTION (Bullding/Mobile Home Property ) (See instructions for inore information.) John serena 28 street Road 28 street Road sanfrasco CT12345 sanfrasco CT12345 Requested By: Victorian Borrower: John serena 3. LENDER/SERVICER ID # 4. LOAN IDENTIFIER 5. AMOUNT OF FLOOD INSURANCE REQUIRED NMLS 50635 210333443500 SECTION Il ‘A. NATIONAL FLOOD INSURANCE PROGRAM (NFIP) COMMUNITY JURISDICTION 1. NFIP Community Name 2. County(ies) 3. Slate 4. NFIP Community Number NORTH FAYETTE, TOWNSHIP OF ALLEGHENY PA 420085 B. NATIONAL FLOOD INSURANCE PROGRAM (NFIP) DATA AFFECTING BUILDING/MOBILE HOME 1. NFIP Map Number or Community-Panel Number | 2. NFIP Map Panet 3. Is there a Letter of Map Change (LOMC)? (Community name, if not the same as "A") Effective/Revised
# ...

# %%
str1 = str1.replace(':',"")

# %% [markdown]
# #

# %%
str1 = str1.replace('?','')

# %%
str1
# Out:
# 'DEPARTMENT OF HOMELAND SECURITY Federal Emergency Management Agency OMB Controi No 1660-0040 STANDARD FLOOD HAZARD DETERMINATION FORM SFHDF Expires 10/31/18 SECTION  - LOAN INFORMATION 1 LENDER/SERVICER NAME AND ADDRESS 2 COLLATERAL DESCRIPTION Bullding/Mobile Home Property  See instructions for inore information John serena 28 street Road 28 street Road sanfrasco CT12345 sanfrasco CT12345 Requested By Victorian Borrower John serena 3 LENDER/SERVICER ID  4 LOAN IDENTIFIER 5 AMOUNT OF FLOOD INSURANCE REQUIRED NMLS 50635 210333443500 SECTION Il ‘A NATIONAL FLOOD INSURANCE PROGRAM NFIP COMMUNITY JURISDICTION 1 NFIP Community Name 2 Countyies 3 Slate 4 NFIP Community Number NORTH FAYETTE TOWNSHIP OF ALLEGHENY PA 420085 B NATIONAL FLOOD INSURANCE PROGRAM NFIP DATA AFFECTING BUILDING/MOBILE HOME 1 NFIP Map Number or Community-Panel Number  2 NFIP Map Panet 3 Is there a Letter of Map Change LOMC Community name if not the same as "A" Effective/Revised Date x No 42003c 0304H 09/26/14 1 YES {
# ...

# %%
from sklearn.linear_model import LinearRegression

# %%
lm=LinearRegression()

# %% [markdown]
# str2

# %%
import os

os.getcwd()
# Out:
# 'C:\\Users\\cyadav\\Excelr-R-assignement'

# %%
from PIL import Image

# %%
image = Image.open('Appraisal-MI211044555_000001_C0-000001.png')

# %%
croppedimg = image.crop((166, 154, 650, 180))
croppedimg
# Out:
# <PIL.Image.Image image mode=RGB size=484x26>

# %%
image
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=1275x2100>

# %%
import numpy as np
import cv2 as cv
from matplotlib import pyplot as plt
img = cv.imread('Appraisal-MI211044555_000001_C0-000001.png',0)
# Initiate ORB detector
orb = cv.ORB_create()
# find the keypoints with ORB
kp = orb.detect(img,None)
# compute the descriptors with ORB
kp, des = orb.compute(img, kp)
# draw only keypoints location,not size and orientation
img2 = cv.drawKeypoints(img, kp, None, color=(0,255,0), flags=0)
plt.imshow(img2), plt.show()
# Out:
# (<matplotlib.image.AxesImage at 0x1819ba93190>, None)

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\cyadav\\Excelr-R-assignement'

# %%
ll = os.listdir()

# %%
for f in ll:
    s = f.split('.',1)
    s.reverse()
    
    if s[0] == "png":
        print(f)
# Out:
# Appraisal-MI211044555_000001_C0-000001.png
# binary.png
# contours.png
# Name Affidavit-MI210517426_000844_C0-000001.png
# Standard Flood Hazard Determination-MI210517471_000269_C0-000001.png

# %%
ll
# Out:
# ['.ipynb_checkpoints',
#  '001_Appraisal_1004.pdf',
#  'Appraisal-MI211044555_000001_C0-000001.png',
#  'Association Rule',
#  'binary.png',
#  'book.csv',
#  'Capture.PNG',
#  'contours.png',
#  'Decision_tree',
#  'en_core_web_sm-3.1.0-py3-none-any.whl',
#  'KNN',
#  'Libraries_used_assignment.xlsx',
#  'Name Affidavit-MI210517426_000844_C0-000001.png',
#  'Niave Bayes',
#  'PCA',
#  'perlineanisha',
#  'Problem Statement (RS).txt',
#  'Random_forest',
#  'Standard Flood Hazard Determination-MI210517471_000269_C0-000001.png',
#  'Standard Flood Hazard Determination-MI210517471_000269_C0-000001.png.png',
#  'testing',
#  'Text Mining',
#  'Untitled Folder 1',
#  'Untitled.ipynb']

# %%
# Out:
# ['Untitled', 'ipynb']

# %%
s.reverse()

# %%
s[0]
# Out:
# 'ipynb'
